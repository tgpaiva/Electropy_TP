# %% [markdown]
# # Libraries

# %%
import sys
from pathlib import Path
sys.path.append('..')
from autolab_funcs import * 
cwd = Path.cwd()

# %% [markdown]
# # Galvanostactic Charge-Discharge

# %%
path = cwd / 'TestData/T27_3_GCD'
name, GCD_data = import_data(path)
print(name)
plot_gcd_curve(GCD_data,save_plot = 'y', outname=name)
calculate_capacitance(GCD_data, ohmic_drop=False, save_results='y',outname=name)
# Out:
# T27_3_GCD

# %% [markdown]
# # Cyclic Voltammetry

# %%
path = cwd / 'TestData/T27_1_CV'
name, CV_data = import_data(path)
plot_cv(CV_data, normalize = True, active_mass=0.1E-3, saveplot='y', outname=name)
# Out:
# /Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/CORKCAP_2022.05187.PTDC/CorkCapPy/Test/../autolab_funcs.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_3rd_curve[n]['WE(1).Current (A)'] = cv_3rd_curve[n]['WE(1).Current (A)'] / active_mass
