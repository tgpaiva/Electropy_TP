# %%
import sys
from pathlib import Path
sys.path.append('..')
from gamry_funcs import * 
cwd = Path.cwd()

# %% [markdown]
# # GCD

# %%
path = cwd / 'TestData' / 'COF' / 'GCD'

GCD_files = import_gamry(path)
data = parse_gcd(GCD_files)
plot_gcd(data, saveplot = 'y', outname = 'T6_1')
calculate_capacitance(data, saveresults='y', outname = 'T6_1')
# Out:
#    Q charge (F/g)  Q discharge (F/g)  Coulombic efficiency (%)  Charge Time  \
# 0       45.864090          39.280051                 85.644456        38.87
# 1       18.700565          18.440342                 98.608476        15.81
# 2       11.239672          11.879906                105.696203         9.48
# 3        7.817754           8.732597                111.702128         6.58
# 4        5.822926           6.870814                117.995910         4.89
# 5        2.068879           3.283744                158.720930         1.72
#
#    Discharge Time  Energy density charge  Energy density discharge
# 0           33.29              16.471240                 14.106704
# 1           15.59               6.683116                  6.590119
# 2           10.02               3.997910                  4.225639
# 3            7.35               2.769107                  3.093152
# 4            5.77               2.053272                  2.422777
# ...

# %% [markdown]
# # CV

# %%
path = cwd / 'TestData' / 'COF' / 'CV'

cv_files = import_gamry(path)
data = parse_cv(cv_files)
plot_cv(data, normalize=True, active_mass=0.1E-3, outname = 'T6_1_CV')
