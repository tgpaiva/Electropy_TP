# %%
import sys
from pathlib import Path
sys.path.append('/Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/CORKCAP_2022.05187.PTDC/CorkCapPy')
from GamryFuncs import * 
cwd = Path.cwd()

# %%
folderlist = ['Toray_sample3_KOH_1M',
            'Toray_sample5_KOH_1M',
            'Toray_OER'
            ]

# %%
pathlist = [Path.home() / 'Downloads' / 'Alexandre'/ foldername for foldername in folderlist]
lsv_files_list = [import_gamry(pathtofile) for pathtofile in pathlist]
lsv_data_list = [parse_lsv(nameoffile) for nameoffile in lsv_files_list]

# %%
colors = ['black', '#E82B23', '#E8237D']

fig, ax = plt.subplots()

for n in range (len(lsv_data_list)):
    plot_lsv(lsv_data_list[n],ax = ax, color_ = colors[n])

ax.set_ylim([0, 20E-3])
ax.set_xlim([1.4, 2])

ax.legend()
plt.show()
# Out:
# /var/folders/1b/dxlb9gtd5yj3tch6qdgq6mhw0000gn/T/ipykernel_12465/1767923407.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
plot_tafel(lsv_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_tafel(lsv_data)
#
# NameError: name 'lsv_data' is not defined

# %%
calculate_tafel_slope(lsv_data)
