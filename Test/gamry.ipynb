# %%
import sys
sys.path.append('/Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/CORKCAP_2022.05187.PTDC/CorkCapPy')
from GamryFuncs import *

# %% [markdown]
# # CV

# %%
path = '/Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/CORKCAP_2022.05187.PTDC/Gamry1000EP6/T6_1/CV/'

CV_files = import_gamry(path)
data = parse_cv(CV_files)
plot_cv(data, outname = 'T6_1_CV')

# %% [markdown]
# # GCD

# %%
path = '/Users/tiagopaiva/Library/CloudStorage/OneDrive-UniversidadedeLisboa/CORKCAP_2022.05187.PTDC/Gamry1000EP6/T6_1/GCD/'

GCD_files = import_gamry(path)
data = parse_gcd(GCD_files)
plot_gcd(data, saveplot = 'n', saveresults = 'n', outname = 'T6_1')
